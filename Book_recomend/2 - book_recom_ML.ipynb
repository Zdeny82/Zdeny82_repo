# %%
# import
import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# # ML

# %% [markdown]
# ### Loading clean and merged data

# %%
# load cleaned data = dataset_lowercase
dataset_lowercase = pd.read_csv('Cleaned_Book_ETL.csv', encoding='UTF-8', sep=',')

# %%
# Convert data types

column_types = {
    'User-ID': 'int64',
    'ISBN': 'string',
    'Book-Rating': 'int64',
    'Book-Title': 'string',
    'Book-Author': 'string',
    'Year-Of-Publication': 'int64',  # nebo 'string', pokud jsou hodnoty smíšené
    'Publisher': 'string',
    'Image-URL-S': 'string',
    'Image-URL-M': 'string',
    'Image-URL-L': 'string'
}

# Data types conversion
for column, dtype in column_types.items():
    dataset_lowercase[column] = dataset_lowercase[column].astype(dtype)

# %%
columns_to_drop = ['Image-URL-S', 'Image-URL-M']

# redundant columns
dataset_lowercase = dataset_lowercase.drop(columns=columns_to_drop)
dataset_lowercase
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276726  0155061224            5
# 1        276729  052165615x            3
# 2        276729  0521795028            6
# 3        276744  038550120x            7
# 4        276747  0060517794            9
# ...         ...         ...          ...
# 383815   276704  0743211383            7
# 383816   276704  0806917695            5
# 383817   276704  1563526298            9
# 383818   276709  0515107662           10
# 383819   276721  0590442449           10
#
#                                                Book-Title        Book-Author  \
# 0                                        rites of passage         judith rae
# 1                                          help!: level 1      philip prowse
# 2       the amsterdam connection : level 4 (cambridge ...        sue leather
# 3                                         a painted house       john grisham
# 4                                little altars everywhere      rebecca wells
# ...                                                   ...                ...
# 383815                                       dreamcatcher       stephen king
# 383816  perplexing lateral thinking puzzles: scholasti...        paul sloane
# 383817  get clark smart : the ultimate guide for the s...       clark howard
# 383818   the sherbrooke bride (bride trilogy (paperback))  catherine coulter
# 383819                                  fourth grade rats     jerry spinelli
#
#         Year-Of-Publication                   Publisher  \
# 0                      2001                      heinle
# 1                      1999  cambridge university press
# 2                      2001  cambridge university press
# 3                      2001                   doubleday
# 4                      2003                 harpertorch
# ...                     ...                         ...
# 383815                 2001                    scribner
# 383816                 1997         sterling publishing
# 383817                 2000            longstreet press
# 383818                 1996                  jove books
# 383819                 1996                  scholastic
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0155061224.0...
# 1       http://images.amazon.com/images/P/052165615X.0...
# 2       http://images.amazon.com/images/P/0521795028.0...
# 3       http://images.amazon.com/images/P/038550120X.0...
# 4       http://images.amazon.com/images/P/0060517794.0...
# ...                                                   ...
# 383815  http://images.amazon.com/images/P/0743211383.0...
# 383816  http://images.amazon.com/images/P/0806917695.0...
# 383817  http://images.amazon.com/images/P/1563526298.0...
# 383818  http://images.amazon.com/images/P/0515107662.0...
# 383819  http://images.amazon.com/images/P/0590442449.0...
#
# [383820 rows x 8 columns]

# %%
# Check for duplicates - one more time
print(dataset_lowercase.duplicated().sum())  # Počet duplicitních řádků
# Out:
# 0

# %% [markdown]
# ## Filter before ML ?

# %%
# FILTER data before pivot - Unnecessary - filter in APP

# Filter *: uživatelé, kteří hodnotili alespoň 2 knihy - není potřeba pro ML model důležitá

# Default Filter 0: uživatelé, kteří hodnotili alespoň 10 knih = 255000 záznamů
# Frontend Filter 1: determinative readers - uživatelé, kteří hodnotili knihu "The Fellowship of the Ring (The Lord of the Rings, Part 1)" od autora Tolkien = 144 záznamů příliš restriktivní

filter_df = dataset_lowercase.copy()

book_counts = filter_df.groupby('User-ID')['Book-Rating'].count()
# dataset_lowercase['User-ID'].loc[dataset_lowercase['User-ID'].isin(book_counts)]
book_counts = book_counts[book_counts > 10]

dataset_lowercase = filter_df.loc[filter_df['User-ID'].isin(book_counts.index)]

# %%
# SET test
chosen_book = 'the fellowship of the ring (the lord of the rings, part 1)'
chosen_book_readers = dataset_lowercase.loc[dataset_lowercase['Book-Title'] == chosen_book, 'User-ID']

books_of_chosen_readers = dataset_lowercase.loc[dataset_lowercase['User-ID'].isin(chosen_book_readers)]
books_of_chosen_readers.head()
# Out:
#       User-ID        ISBN  Book-Rating  \
# 2252      254  0060502320            7
# 2253      254  0060934700            9
# 2254      254  0060976977            7
# 2255      254  0064471047            7
# 2256      254  0066238501            5
#
#                                              Book-Title     Book-Author  \
# 2252                                 i've got you, babe   karen kendall
# 2253    smoke and mirrors: short fictions and illusions     neil gaiman
# 2254  amazing grace : lives of children and the cons...  jonathan kozol
# 2255  the lion, the witch, and the wardrobe (the chr...     c. s. lewis
# 2256                      complete chronicles of narnia     c. s. lewis
#
#       Year-Of-Publication                     Publisher  \
# 2252                 2002                          avon
# 2253                 2001                     perennial
# 2254                 1996                     perennial
# 2255                 1994                 harpercollins
# 2256                 2001  harpercollins juvenile books
#
#                                             Image-URL-L
# 2252  http://images.amazon.com/images/P/0060502320.0...
# 2253  http://images.amazon.com/images/P/0060934700.0...
# 2254  http://images.amazon.com/images/P/0060976977.0...
# 2255  http://images.amazon.com/images/P/0064471047.0...
# 2256  http://images.amazon.com/images/P/0066238501.0...

# %%
# pivot table
book_pivot = books_of_chosen_readers.pivot_table(columns='User-ID', index='Book-Title', values='Book-Rating') # pivot_table umí agregovat a umí pracovat s NaN
book_pivot.fillna(0, inplace=True) # Memory-efficient
book_pivot
# Out:
# User-ID                                             254     1674    11676   \
# Book-Title
#  earth prayers from around the world: 365 praye...     0.0     0.0     0.0
#  nonbook materials: the organization of integra...     0.0     0.0     0.0
# !yo!                                                   0.0     0.0     0.0
# 'a hell of a place to lose a cow': an american ...     0.0     0.0     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0     0.0     2.0
# ...                                                    ...     ...     ...
# zwгѓ?г‚в¶lf.                                           0.0     0.0     7.0
# гѓ?ngeles fugaces (falling angels)                     0.0     0.0     0.0
# гѓ?г‚?ber das fernsehen.                               0.0     0.0     8.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0     0.0     0.0
# г‚вўcorre, perro, corre!                               0.0     0.0    10.0
#
# User-ID                                             11944   16601   16795   \
# Book-Title
#  earth prayers from around the world: 365 praye...     0.0     0.0     0.0
#  nonbook materials: the organization of integra...     0.0     0.0     0.0
# !yo!                                                   0.0     0.0     0.0
# 'a hell of a place to lose a cow': an american ...     0.0     0.0     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zwгѓ?г‚в¶lf.                                           0.0     0.0     0.0
# гѓ?ngeles fugaces (falling angels)                     0.0     0.0     0.0
# гѓ?г‚?ber das fernsehen.                               0.0     0.0     0.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0     0.0     0.0
# г‚вўcorre, perro, corre!                               0.0     0.0     0.0
#
# User-ID                                             22818   23571   23699   \
# Book-Title
#  earth prayers from around the world: 365 praye...     0.0     0.0     0.0
#  nonbook materials: the organization of integra...     0.0     0.0     0.0
# !yo!                                                   0.0     0.0     0.0
# 'a hell of a place to lose a cow': an american ...     0.0     0.0     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zwгѓ?г‚в¶lf.                                           0.0     0.0     0.0
# гѓ?ngeles fugaces (falling angels)                     0.0     0.0     0.0
# гѓ?г‚?ber das fernsehen.                               0.0     0.0     0.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0     0.0     0.0
# г‚вўcorre, perro, corre!                               0.0     0.0     0.0
#
# User-ID                                             23872   ...  254206  \
# Book-Title                                                  ...
#  earth prayers from around the world: 365 praye...     0.0  ...     0.0
#  nonbook materials: the organization of integra...     0.0  ...     0.0
# !yo!                                                   0.0  ...     0.0
# 'a hell of a place to lose a cow': an american ...     0.0  ...     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0  ...     0.0
# ...                                                    ...  ...     ...
# zwгѓ?г‚в¶lf.                                           0.0  ...     0.0
# гѓ?ngeles fugaces (falling angels)                     0.0  ...     0.0
# гѓ?г‚?ber das fernsehen.                               0.0  ...     0.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0  ...     0.0
# г‚вўcorre, perro, corre!                               0.0  ...     0.0
#
# User-ID                                             258614  259057  259901  \
# Book-Title
#  earth prayers from around the world: 365 praye...     0.0     0.0     0.0
#  nonbook materials: the organization of integra...     0.0     0.0     0.0
# !yo!                                                   0.0     0.0     0.0
# 'a hell of a place to lose a cow': an american ...     0.0     0.0     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zwгѓ?г‚в¶lf.                                           0.0     0.0     0.0
# гѓ?ngeles fugaces (falling angels)                     0.0     0.0     0.0
# гѓ?г‚?ber das fernsehen.                               0.0     0.0     0.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0     0.0     0.0
# г‚вўcorre, perro, corre!                               0.0     0.0     0.0
#
# User-ID                                             260419  265313  271176  \
# Book-Title
#  earth prayers from around the world: 365 praye...     0.0     0.0     0.0
#  nonbook materials: the organization of integra...     0.0     0.0     0.0
# !yo!                                                   0.0     0.0     0.0
# 'a hell of a place to lose a cow': an american ...     0.0     0.0     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zwгѓ?г‚в¶lf.                                           0.0     0.0     0.0
# гѓ?ngeles fugaces (falling angels)                     0.0     0.0     0.0
# гѓ?г‚?ber das fernsehen.                               0.0     0.0     0.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0     0.0     0.0
# г‚вўcorre, perro, corre!                               0.0     0.0     0.0
#
# User-ID                                             274393  276050  276313
# Book-Title
#  earth prayers from around the world: 365 praye...     0.0     0.0     0.0
#  nonbook materials: the organization of integra...     0.0     0.0     0.0
# !yo!                                                   0.0     0.0     0.0
# 'a hell of a place to lose a cow': an american ...     0.0     0.0     0.0
# 'eine gute frau hat keinen kopf'. europгѓ?г‚в¤i...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# zwгѓ?г‚в¶lf.                                           0.0     0.0     0.0
# гѓ?ngeles fugaces (falling angels)                     0.0     0.0     0.0
# гѓ?г‚?ber das fernsehen.                               0.0     0.0     0.0
# г‚вїeres tu mi mamгѓвў?/are you my mother?             0.0     0.0     0.0
# г‚вўcorre, perro, corre!                               0.0     0.0     0.0
#
# [17529 rows x 125 columns]

# %%
# sparse matrix
book_sparse = csr_matrix(book_pivot)

# %%
# Unsupervised learner for implementing neighbor searches
# algorithm{‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’}, default=’auto’ will attempt to decide the most appropriate algorithm based on the values passed to fit method.
model = NearestNeighbors(algorithm='brute')
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
# model vrací dvě hodnoty:
# 1) distances: Vzdálenosti mezi danou knihou (chosen_book) a jejími nejbližšími sousedy
# 2) suggestions: Indexy knih, které jsou nejbližší sousedé k dané knize (chosen_book)

# .values.reshape(1, -1): Převede řádek na numpy pole a přetvoří jej do tvaru (1, n), kde n je počet sloupců. To je nutné, protože kneighbors očekává 2D pole.
distances, suggestions = model.kneighbors(book_pivot.loc[[chosen_book]].values, n_neighbors=10) # n_neighbors=5, default
suggestions
# Out:
# array([[13378, 15544, 14924,  5740, 13746,  5748,  5744,  5745,  5750,
#          5752]], dtype=int64)

# %%
# print all the suggested books
for i in range(len(suggestions)):
  print(book_pivot.index[suggestions[i]])
# Out:
# Index(['the fellowship of the ring (the lord of the rings, part 1)',
#        'the two towers (the lord of the rings, part 2)',
#        'the return of the king (the lord of the rings, part 3)',
#        'harry potter and the chamber of secrets (book 2)',
#        'the hobbit : the enchanting prelude to the lord of the rings',
#        'harry potter and the prisoner of azkaban (book 3)',
#        'harry potter and the goblet of fire (book 4)',
#        'harry potter and the order of the phoenix (book 5)',
#        'harry potter and the sorcerer's stone (book 1)',
#        'harry potter and the sorcerer's stone (harry potter (paperback))'],
#       dtype='string', name='Book-Title')
